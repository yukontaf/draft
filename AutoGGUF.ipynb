# %%
# %cd /Users/gsokolov

MODEL_ID = "deepseek-ai/deepseek-moe-16b-base"
QUANTIZATION_METHODS = "q8_0"
QUANTIZATION_METHODS = QUANTIZATION_METHODS.replace(" ", "").split(",")

username = "symbyax"
token = "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"

MODEL_NAME = MODEL_ID.split("/")[-1]

# !git clone https://github.com/ggerganov/llama.cpp
# %cd llama.cpp/
# !git pull && make clean && make
# %cd ..
# !pip install -r /Users/gsokolov/llama.cpp/requirements.txt

# !git clone https://huggingface.co/{MODEL_ID}

fp16 = f"{MODEL_NAME}/{MODEL_NAME.lower()}.fp16.bin"
# !python llama.cpp/convert.py {MODEL_NAME} --outtype f16 --outfile {fp16}

for method in QUANTIZATION_METHODS:
    qtype = f"{MODEL_NAME}/{MODEL_NAME.lower()}.{method.upper()}.gguf"
    # !llama.cpp/quantize {fp16} {qtype} {method}
# Out:
# /Users/gsokolov
# Loading model file deepseek-moe-16b-base/model-00001-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00001-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00002-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00003-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00004-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00005-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00006-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00007-of-00007.safetensors
# params = Params(n_vocab=102400, n_embd=2048, n_layer=28, n_ctx=4096, n_ff=10944, n_head=16, n_head_kv=16, n_experts=None, n_experts_used=None, f_norm_eps=1e-06, rope_scaling_type=None, f_rope_freq_base=10000, f_rope_scale=None, n_orig_ctx=None, rope_finetuned=None, ftype=<GGMLFileType.MostlyF16: 1>, path_model=PosixPath('deepseek-moe-16b-base'))
# ...

# %%
# %%bash
# echo ${MODEL_NAME}

# %%
from llm_rs.convert import AutoConverter
from llm_rs import AutoModel, AutoQuantizer
import sys

# define the model which should be converted and an output directory
export_directory = "/Users/gsokolov/text-generation-webui/models"
base_model = MODEL_NAME

# convert the model
converted_model = AutoConverter.convert(base_model, export_directory)

# quantize the model (this step is optional)
quantized_model = AutoQuantizer.quantize(converted_model)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 10
#       7 base_model = MODEL_NAME
#       9 #convert the model
# ---> 10 converted_model = AutoConverter.convert(base_model, export_directory)
#      12 #quantize the model (this step is optional)
#      13 quantized_model = AutoQuantizer.quantize(converted_model)
#
# File ~/anaconda3/lib/python3.11/site-packages/llm_rs/convert/auto_converter.py:29, in AutoConverter.convert(pretrained_model_name_or_path, output_path)
#      27 adapter=None
#      28 if architecture not in _ARCHITECTURE_CONVERTER_MAP:
# ---> 29     raise ValueError(f"Unsupported architecture '{architecture}' for '{model_name}'")
#      30 adapter = _ARCHITECTURE_CONVERTER_MAP[architecture]
#      32 output_file = build_path(output_path,model_name)
#
# ValueError: Unsupported architecture 'DeepseekForCausalLM' for 'deepseek-moe-16b-base'

# %%
import os

os.environ["MODEL_NAME"] = MODEL_NAME

# %%
# %%bash
# python /Users/gsokolov/llama.cpp/convert.py ${MODEL_NAME} --outtype f16 --skip-unknown
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Loading model file deepseek-moe-16b-base/model-00001-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00001-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00002-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00003-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00004-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00005-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00006-of-00007.safetensors
# Loading model file deepseek-moe-16b-base/model-00007-of-00007.safetensors
# ...

# %%
# !mkdir f'/Users/gsokolov/.cache/lm-studio/{MODEL_NAME}'
# !ln -s {fp16} f'/Users/gsokolov/.cache/lm-studio/{MODEL_NAME}/{qtype}'
# !mv f'/Users/gsokolov/{MODEL_NAME}/{qtype}' f'/Users/gsokolov/text-generation-webui/models/{qtype}'
