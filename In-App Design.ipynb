# %%
import pandas as pd
import scipy as sc
import numpy as np
import scipy.stats as stats
from scipy.stats import shapiro, kstest, ttest_ind, norm, mannwhitneyu, binom
import math
import statsmodels.api as sm
import statsmodels.stats.api as sms
import statsmodels.stats.proportion as proportion
import matplotlib.pyplot as plt
import statsmodels.stats.power as smp
from tqdm.auto import tqdm
from random import randint
import seaborn as sns
from itertools import product
from tqdm.notebook import tqdm
import warnings
from pyperclip import paste, copy
import ipywidgets as widgets
from itertools import product
from IPython.display import Markdown as md

# %load_ext google.cloud.bigquery
warnings.filterwarnings("ignore")

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

pal = [
    "#be0707",
    "#dc3248",
    "#ef5a80",
    "#f982b2",
    "#fca9dd",
    "#ffcfff",
    "#eebdfb",
    "#daacf9",
    "#c19cf8",
    "#a48ef7",
    "#7e82f7",
]

sns.set_theme(style="white", palette=pal, rc={"figure.figsize": (12, 8)})
plt.rcParams["figure.figsize"] = (12, 8)
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery tables
# select *, CONCAT(table_catalog,".",  table_schema, ".", table_name) AS table_ref
# FROM `analytics-147612.wh_raw`.INFORMATION_SCHEMA.TABLES
# WHERE table_type = "BASE TABLE"
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
tables_list = tables["table_ref"].values

# %%
from google.cloud import bigquery

client = bigquery.Client(location="US")

# %%
tables["ddl"].iloc[0]
# Out:
# 'CREATE TABLE `analytics-147612.wh_raw.copy_trade_log`\n(\n  id INT64,\n  type STRING,\n  date TIMESTAMP,\n  master_account_number INT64,\n  copier_account_number INT64,\n  copier_user_id INT64,\n  commission INT64,\n  amount FLOAT64,\n  deposit_percentage INT64,\n  commission_revshare INT64,\n  commission_type STRING,\n  source STRING,\n  mobile_app STRING,\n  volume_ratio INT64,\n  is_trade_notifications_enabled INT64\n);'

# %%
t = []
for table_ref in tables_list:
    # Fetch the table
    table = client.get_table(table_ref)

    # Iterate over the schema and print details
    for field in table.schema:
        if field.field_type == "STRING" and "event" in field.name:
            # print(table_ref)
            # print(f"Field: {field.name}, Type: {field.field_type}, Mode: {field.mode}")
            t.append([table_ref, field.name])

# %%
t
# Out:
# [['analytics-147612.wh_raw.webinar_event_bonuses_raw', 'webinar_event'],
#  ['analytics-147612.wh_raw.lifetime_events', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctamarkets',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctamarkets',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctamarkets',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctamarkets',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctamarkets',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctamarkets',
#   'event_source'],
#  ['analytics-147612.wh_raw.intercom_chat_errors', 'event_value'],
#  ['analytics-147612.wh_raw.intercom_chat_errors', 'event_name'],
#  ['analytics-147612.wh_raw.touches_appsflyer', 'event_nature'],
#  ['analytics-147612.wh_raw.partner_lifetime_periods_tmp', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_id1552179961',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_id1552179961',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_id1552179961',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_id1552179961',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_id1552179961',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_id1552179961',
#   'event_source'],
#  ['analytics-147612.wh_raw.touches_appsflyer_lite_app', 'event_nature'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctaeight',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctaeight',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctaeight',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctaeight',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctaeight',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctaeight',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_complatform8',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_complatform8',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_complatform8',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_complatform8',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_complatform8',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_complatform8',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctapulse',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctapulse',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctapulse',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctapulse',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctapulse',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctapulse',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comtradosphere',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comtradosphere',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comtradosphere',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comtradosphere',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comtradosphere',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comtradosphere',
#   'event_source'],
#  ['analytics-147612.wh_raw.zendesk_events', 'event_type'],
#  ['analytics-147612.wh_raw.zendesk_events', 'event_properties'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctabroker',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctabroker',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctabroker',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctabroker',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctabroker',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctabroker',
#   'event_source'],
#  ['analytics-147612.wh_raw.feed_user_channel_events', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_id1552179961',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_id1552179961',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_id1552179961',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_id1552179961',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_id1552179961',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_id1552179961',
#   'event_source'],
#  ['analytics-147612.wh_raw.ml_50_notifcation', 'event'],
#  ['analytics-147612.wh_raw.partner_lifetime_events', 'event_type'],
#  ['analytics-147612.wh_raw.webinar_event_speakers_raw', 'webinar_event'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxtrading',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxtrading',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxtrading',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxtrading',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxtrading',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxtrading',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctapulse',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctapulse',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctapulse',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctapulse',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctapulse',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctapulse',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comocta8', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comocta8', 'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comocta8',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comocta8',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comocta8',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comocta8', 'event_source'],
#  ['analytics-147612.wh_raw.ms_offers_raw_events', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_complatform8',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_complatform8',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_complatform8',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_complatform8',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_complatform8',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_complatform8',
#   'event_source'],
#  ['analytics-147612.wh_raw.bms_places', 'facebook_event'],
#  ['analytics-147612.wh_raw.mobile_lite_app', 'event_name'],
#  ['analytics-147612.wh_raw.mobile_lite_app', 'event_value'],
#  ['analytics-147612.wh_raw.mobile_lite_app', 'event_revenue'],
#  ['analytics-147612.wh_raw.mobile_lite_app', 'event_revenue_usd'],
#  ['analytics-147612.wh_raw.mobile_lite_app', 'event_revenue_currency'],
#  ['analytics-147612.wh_raw.mobile_lite_app', 'event_source'],
#  ['analytics-147612.wh_raw.mobile_lite_app', 'event_type'],
#  ['analytics-147612.wh_raw.ab_tests_hour_dynamics_non_agg', 'event_time'],
#  ['analytics-147612.wh_raw.verifications_queue_events', 'event'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctapulse',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctapulse',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctapulse',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctapulse',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctapulse',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctapulse',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxtrading',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxtrading',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxtrading',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxtrading',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxtrading',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxtrading',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxcopytrade',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxcopytrade',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxcopytrade',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxcopytrade',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxcopytrade',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafxcopytrade',
#   'event_source'],
#  ['analytics-147612.wh_raw.mobile_learning_app', 'event_name'],
#  ['analytics-147612.wh_raw.mobile_learning_app', 'event_value'],
#  ['analytics-147612.wh_raw.mobile_learning_app', 'event_revenue'],
#  ['analytics-147612.wh_raw.mobile_learning_app', 'event_revenue_usd'],
#  ['analytics-147612.wh_raw.mobile_learning_app', 'event_revenue_currency'],
#  ['analytics-147612.wh_raw.mobile_learning_app', 'event_source'],
#  ['analytics-147612.wh_raw.mobile_learning_app', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafx',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafx',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafx',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafx',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafx',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafx',
#   'event_source'],
#  ['analytics-147612.wh_raw.activations_with_user_id_and_rates_for_cpa',
#   'event_name'],
#  ['analytics-147612.wh_raw.bonus_risk_ab_test', 'event'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls', 'event_time'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls', 'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls', 'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls', 'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls', 'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls', 'event_source'],
#  ['analytics-147612.wh_raw.ecalendar_events', 'eventcode'],
#  ['analytics-147612.wh_raw.ecalendar_events', 'eventcode_uniq'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comtradosphere',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comtradosphere',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comtradosphere',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comtradosphere',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comtradosphere',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comtradosphere',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxcopytrade',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxcopytrade',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxcopytrade',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxcopytrade',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxcopytrade',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxcopytrade',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxtrading',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxtrading',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxtrading',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxtrading',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxtrading',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafxtrading',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comocta8',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comocta8',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comocta8',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comocta8',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comocta8',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comocta8',
#   'event_source'],
#  ['analytics-147612.wh_raw.ms_offers_events', 'event_name'],
#  ['analytics-147612.wh_raw.partner_lifetime_periods', 'event_type'],
#  ['analytics-147612.wh_raw.mobile_trading_webview_onload_events',
#   'event_name'],
#  ['analytics-147612.wh_raw.mobile_trading_webview_onload_events',
#   'event_value'],
#  ['analytics-147612.wh_raw.intercom_events', 'event'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_uninstalls_with_channel',
#   'event_time'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_uninstalls_with_channel',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_uninstalls_with_channel',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_uninstalls_with_channel',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_uninstalls_with_channel',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_uninstalls_with_channel',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_uninstalls_with_channel',
#   'event_source'],
#  ['analytics-147612.wh_raw.touches_appsflyer_ios', 'event_nature'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comtradosphere',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comtradosphere',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comtradosphere',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comtradosphere',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comtradosphere',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comtradosphere',
#   'event_source'],
#  ['analytics-147612.wh_raw.activations_with_user_id_for_cpa', 'event_name'],
#  ['analytics-147612.wh_raw.activations_with_touches_for_cpa', 'event_name'],
#  ['analytics-147612.wh_raw.mobile_advertising_id_firebase_id_periods_full',
#   'events'],
#  ['analytics-147612.wh_raw.mobile_advertising_id_firebase_id_periods_full',
#   'new_events'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comocta8',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comocta8',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comocta8',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comocta8',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comocta8',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comocta8',
#   'event_source'],
#  ['analytics-147612.wh_raw.lifetime_periods', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_copytrade_events_with_channel',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_copytrade_events_with_channel',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_copytrade_events_with_channel',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_copytrade_events_with_channel',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_copytrade_events_with_channel',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_copytrade_events_with_channel',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_copytrade_events_with_channel',
#   'event_type'],
#  ['analytics-147612.wh_raw.touches_appsflyer_copytrade', 'event_nature'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls_copytrade', 'event_time'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls_copytrade', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls_copytrade', 'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls_copytrade', 'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls_copytrade',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls_copytrade',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstalls_copytrade', 'event_source'],
#  ['analytics-147612.wh_raw.mobile_devices_info', 'event_hash'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafx', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafx', 'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafx',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafx',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafx',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctafx',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctaeight',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctaeight',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctaeight',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctaeight',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctaeight',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctaeight',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_id1552179961',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_id1552179961',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_id1552179961',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_id1552179961',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_id1552179961',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_id1552179961',
#   'event_source'],
#  ['analytics-147612.wh_raw.mobile_appsflyer', 'event_name'],
#  ['analytics-147612.wh_raw.mobile_appsflyer', 'event_value'],
#  ['analytics-147612.wh_raw.mobile_appsflyer', 'event_revenue'],
#  ['analytics-147612.wh_raw.mobile_appsflyer', 'event_revenue_usd'],
#  ['analytics-147612.wh_raw.mobile_appsflyer', 'event_revenue_currency'],
#  ['analytics-147612.wh_raw.mobile_appsflyer', 'event_source'],
#  ['analytics-147612.wh_raw.mobile_appsflyer', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxcopytrade',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxcopytrade',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxcopytrade',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxcopytrade',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxcopytrade',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctafxcopytrade',
#   'event_source'],
#  ['analytics-147612.wh_raw.ms_offers_raw_events_hourly', 'event_name'],
#  ['analytics-147612.wh_raw.conversions_30_day_from_install', 'event_name'],
#  ['analytics-147612.wh_raw.conversions_30_day_from_install', 'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_events_with_channel',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_events_with_channel',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_events_with_channel',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_events_with_channel',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_events_with_channel',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_events_with_channel',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_general_app_events_with_channel',
#   'event_type'],
#  ['analytics-147612.wh_raw.ms_offers_events_hourly', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctamarkets',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctamarkets',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctamarkets',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctamarkets',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctamarkets',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctamarkets',
#   'event_source'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_ios', 'event_name'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_ios', 'event_value'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_ios', 'event_revenue'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_ios', 'event_revenue_usd'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_ios', 'event_revenue_currency'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_ios', 'event_source'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_ios', 'event_type'],
#  ['analytics-147612.wh_raw.touches_inside_the_channels', 'event'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_stream', 'event_name'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_stream', 'event_value'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_stream', 'event_revenue'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_stream', 'event_revenue_usd'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_stream', 'event_revenue_currency'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_stream', 'event_source'],
#  ['analytics-147612.wh_raw.mobile_appsflyer_stream', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctabroker',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctabroker',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctabroker',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctabroker',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctabroker',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctabroker',
#   'event_source'],
#  ['analytics-147612.wh_raw.ab_tests_communication_info', 'event_time'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctamarkets',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctamarkets',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctamarkets',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctamarkets',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctamarkets',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_installs_fraud_comoctamarkets',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_lite_app_events_with_channel',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_lite_app_events_with_channel',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_lite_app_events_with_channel',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_lite_app_events_with_channel',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_lite_app_events_with_channel',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_lite_app_events_with_channel',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_lite_app_events_with_channel',
#   'event_type'],
#  ['analytics-147612.wh_raw.mobile_copytrade', 'event_name'],
#  ['analytics-147612.wh_raw.mobile_copytrade', 'event_value'],
#  ['analytics-147612.wh_raw.mobile_copytrade', 'event_revenue'],
#  ['analytics-147612.wh_raw.mobile_copytrade', 'event_revenue_usd'],
#  ['analytics-147612.wh_raw.mobile_copytrade', 'event_revenue_currency'],
#  ['analytics-147612.wh_raw.mobile_copytrade', 'event_source'],
#  ['analytics-147612.wh_raw.mobile_copytrade', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctabroker',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctabroker',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctabroker',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctabroker',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctabroker',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctabroker',
#   'event_source'],
#  ['analytics-147612.wh_raw.webinars_raw', 'webinar_event_slug'],
#  ['analytics-147612.wh_raw.feed_user_channel_events_generated', 'event_name'],
#  ['analytics-147612.wh_raw.feed_user_channel_events_generated', 'event_dt'],
#  ['analytics-147612.wh_raw.ecalendar_events_translations', 'eventcode'],
#  ['analytics-147612.wh_raw.webinar_event_communication_settings_raw',
#   'webinar_event'],
#  ['analytics-147612.wh_raw.webinar_event_communication_settings_raw',
#   'event_description'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_complatform8',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_complatform8',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_complatform8',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_complatform8',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_complatform8',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_complatform8',
#   'event_source'],
#  ['analytics-147612.wh_raw.marketing_events_s2s_web_all', 'event_name'],
#  ['analytics-147612.wh_raw.lifetime_periods_tmp', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_ios_events_with_channel', 'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_ios_events_with_channel', 'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_ios_events_with_channel',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_ios_events_with_channel',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_ios_events_with_channel',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_ios_events_with_channel', 'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_ios_events_with_channel', 'event_type'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctaeight',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctaeight',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctaeight',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctaeight',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctaeight',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_uninstall_events_report_comoctaeight',
#   'event_source'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafx',
#   'event_name'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafx',
#   'event_value'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafx',
#   'event_revenue'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafx',
#   'event_revenue_currency'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafx',
#   'event_revenue_usd'],
#  ['analytics-147612.wh_raw.appsflyer_post_attr_installs_fraud_comoctafx',
#   'event_source']]

# %%
from google.cloud import bigquery

# Initialize a BigQuery client
client = bigquery.Client()

# List of table references in the format `project_id.dataset_id.table_id`
table_references = [
    "your-project-id.your-dataset-id.your-table-id1",
    "your-project-id.your-dataset-id.your-table-id2",
    # Add more table references as needed
]

# Iterate over the table references
for table_ref in table_references:
    # Fetch the table
    table = client.get_table(table_ref)

    # Print the table ID
    print(f"Schema for {table_ref}:")

    # Iterate over the schema and print details
    for field in table.schema:
        print(f"Field: {field.name}, Type: {field.field_type}, Mode: {field.mode}")

    # Add a newline for better readability between tables
    print("\n")

# Note: Replace 'your-project-id', 'your-dataset-id', and 'your-table-id' with

# %%
# %%bigquery
# create or replace table dev_gsokolov.segment as (
# SELECT
#   u.user_id,
#   MIN(u.country) as user_country,
#   MIN(ta.trading_account_created_date) AS account_creation_time
# FROM
#   wh_raw.users AS u
#   INNER JOIN amplitude.events_octa_raw_trading_accounts AS ta ON u.user_id = ta.user_id
#   AND ta.platform = 'android'
#   AND ta.server_name = 'real'
#   LEFT JOIN wh_raw.deposits_enhanced AS d ON u.user_id = d.user_id
#   AND ta.trading_account_created_date <= d.created_dt
#   AND d.created_dt
#   < DATE_ADD(ta.trading_account_created_date, INTERVAL 1 HOUR)
# WHERE
#   -- d.user_id IS NULL
#   DATE(u.registered_dt) BETWEEN '2023-06-01' AND '2024-01-01'
# GROUP BY
#   1)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# WITH
#   registeredusers AS (
#     SELECT
#       user_id,
#       country,
#       registered_dt
#     FROM
#       `analytics-147612.wh_raw.users`
#     WHERE
#       DATE(registered_dt) BETWEEN '2023-06-01' AND '2024-01-01'
#       AND country IN (
#         'India',
#         'Indonesia',
#         'Mexico',
#         'Brazil',
#         'Malaysia'
#       )
#   ),
#   androidusers AS (
#     SELECT
#       user_id,
#       MIN(trading_account_created_date) AS first_trading_account_dt
#     FROM
#       `analytics-147612.amplitude.events_octa_raw_trading_accounts`
#     WHERE
#       platform = 'android'
#       AND server_name = 'real'
#       AND user_id IN (
#         SELECT
#           user_id
#         FROM
#           registeredusers
#       )
#     GROUP BY
#       1
#   ),
#   deposits AS (
#     SELECT
#       b.user_id as user_id,
#       MIN(TIMESTAMP_SECONDS(d.created)) AS first_deposit_time
#     FROM
#       wh_raw.deposit_requests d
#       left join wh_raw.billing_accounts b
#       on d.billing_account_id = b.id
#       where b.user_id IN (
#         SELECT
#           user_id
#         FROM
#           registeredusers
#       )
#     GROUP BY
#       b.user_id
#   ),
#   filteredusers AS (
#     SELECT
#       ru.user_id,
#       ru.registered_dt,
#       ru.country,
#       d.first_deposit_time
#     FROM
#       registeredusers AS ru
#       INNER JOIN androidusers AS au ON ru.user_id = au.user_id
#       LEFT JOIN deposits AS d ON ru.user_id = d.user_id
#     WHERE
#       d.user_id IS NULL
#       OR TIMESTAMP_DIFF(
#         d.first_deposit_time,
#         TIMESTAMP(au.first_trading_account_dt),
#         HOUR
#       ) > 1
#   )
# SELECT
#   *
# FROM
#   filteredusers;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           user_id             registered_dt   country  \
# 0        32932941 2023-06-11 22:46:53+00:00    Brazil
# 1        32936351 2023-06-12 03:23:27+00:00    Brazil
# 2        32943594 2023-06-12 11:18:54+00:00    Brazil
# 3        32946875 2023-06-12 14:27:46+00:00    Brazil
# 4        32948748 2023-06-12 16:23:14+00:00    Brazil
# ...           ...                       ...       ...
# 1138984  33802505 2023-07-23 00:11:11+00:00  Malaysia
# 1138985  33827915 2023-07-24 08:24:12+00:00  Malaysia
# 1138986  33720140 2023-07-18 20:59:42+00:00  Malaysia
# 1138987  33758728 2023-07-20 15:54:36+00:00  Malaysia
# 1138988  33751357 2023-07-20 08:45:27+00:00  Malaysia
#
#                first_deposit_time
# 0                             NaT
# 1                             NaT
# 2                             NaT
# 3                             NaT
# 4                             NaT
# ...                           ...
# 1138984                       NaT
# 1138985                       NaT
# 1138986 2023-07-19 11:31:57+00:00
# 1138987                       NaT
# 1138988                       NaT
#
# [1138989 rows x 4 columns]

# %%
s = _42

# %%
s["user_id"].nunique()
# Out:
# 1138989

# %%
s["first_deposit_time"].notna().sum()
# Out:
# 36367

# %%
from pandas_gbq import to_gbq

segment.to_gbq("dev_gsokolov.segment", "analytics-147612", if_exists="replace")
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 5745.62it/s]

# %%
segment
# Out:
#           user_id             registered_dt   country  \
# 0        35933014 2023-11-01 00:35:29+00:00     India
# 1        35933595 2023-11-01 01:27:00+00:00     India
# 2        35933647 2023-11-01 01:32:43+00:00     India
# 3        35934160 2023-11-01 02:15:04+00:00     India
# 4        35934566 2023-11-01 02:50:10+00:00     India
# ...           ...                       ...       ...
# 1102617  32695737 2023-06-01 10:58:33+00:00  Malaysia
# 1102618  32692579 2023-06-01 07:56:01+00:00  Malaysia
# 1102619  32699119 2023-06-01 13:49:06+00:00  Malaysia
# 1102620  32707387 2023-06-01 23:35:18+00:00  Malaysia
# 1102621  32698159 2023-06-01 12:59:50+00:00  Malaysia
#
#          first_trading_account_dt
# 0       2023-11-01 00:37:24+00:00
# 1       2023-11-01 01:28:04+00:00
# 2       2023-11-01 01:33:43+00:00
# 3       2023-11-01 02:21:16+00:00
# 4       2023-12-01 07:35:36+00:00
# ...                           ...
# 1102617 2023-06-01 11:01:23+00:00
# 1102618 2023-06-01 07:57:35+00:00
# 1102619 2023-06-01 13:51:38+00:00
# 1102620 2023-06-07 13:28:12+00:00
# 1102621 2023-06-01 13:03:00+00:00
#
# [1102622 rows x 4 columns]

# %%
from google.cloud import bigquery

# Initialize a BigQuery client
client = bigquery.Client()

# Define the table schema
schema = [
    bigquery.SchemaField("column1", "STRING"),
    bigquery.SchemaField("column2", "INTEGER"),
    bigquery.SchemaField("column3", "FLOAT"),
]

# Define the table reference
table_ref = client.dataset("your_dataset_id").table("your_table_id")

# Define the table object
table = bigquery.Table(table_ref, schema=schema)

# Create the table
client.create_table(table)
# %%bigquery
CREATE OR REPLACE TABLE `your-project-id.your-dataset-id.your-table-id` (
  column1 datatype1,
  column2 datatype2,
  ...
)

# %%
segment
# Out:
#           user_id             registered_dt   country  \
# 0        35933014 2023-11-01 00:35:29+00:00     India
# 1        35933595 2023-11-01 01:27:00+00:00     India
# 2        35933647 2023-11-01 01:32:43+00:00     India
# 3        35934160 2023-11-01 02:15:04+00:00     India
# 4        35934566 2023-11-01 02:50:10+00:00     India
# ...           ...                       ...       ...
# 1102617  32695737 2023-06-01 10:58:33+00:00  Malaysia
# 1102618  32692579 2023-06-01 07:56:01+00:00  Malaysia
# 1102619  32699119 2023-06-01 13:49:06+00:00  Malaysia
# 1102620  32707387 2023-06-01 23:35:18+00:00  Malaysia
# 1102621  32698159 2023-06-01 12:59:50+00:00  Malaysia
#
#          first_trading_account_dt
# 0       2023-11-01 00:37:24+00:00
# 1       2023-11-01 01:28:04+00:00
# 2       2023-11-01 01:33:43+00:00
# 3       2023-11-01 02:21:16+00:00
# 4       2023-12-01 07:35:36+00:00
# ...                           ...
# 1102617 2023-06-01 11:01:23+00:00
# 1102618 2023-06-01 07:57:35+00:00
# 1102619 2023-06-01 13:51:38+00:00
# 1102620 2023-06-07 13:28:12+00:00
# 1102621 2023-06-01 13:03:00+00:00
#
# [1102622 rows x 4 columns]

# %%
# %%bigquery
# SELECT
#     table_name,
#     search(t.ddl, "payment") AS res
# FROM (SELECT
#     table_name,
#     ddl
# FROM wh_raw.INFORMATION_SCHEMA.TABLES) AS t
# WHERE search(t.ddl, "payment") = True
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                       table_name   res
# 0                           payment_transactions  True
# 1                                       contests  True
# 2                               cpa_actual_costs  True
# 3            billing_paysystem_user_restrictions  True
# 4   ps_report_to_fims_withdrawals_reconciliation  True
# 5                       rebate_payment_error_log  True
# 6            withdrawal_requests_every_5_minutes  True
# 7                        fraud_flag_every_5_mins  True
# 8      ps_report_to_fims_deposits_reconciliation  True
# 9                    chargebacks_export_prepared  True
# 10                     ps_report_deposits_export  True
# 11                       payment_templates_usage  True
# 12           fims_withdrawals_for_reconciliation  True
# 13                     payment_transactions_slim  True
# 14                                    brandwatch  True
# 15                 payment_systems_finance_stats  True
# 16                              deposit_requests  True
# 17                 ib_costs_from_spreadsheet_raw  True
# 18                               refund_requests  True
# 19                                  deposits_raw  True
# 20                         ps_report_withdrawals  True
# 21                        deposits_transform_tmp  True
# 22                       deposits_with_meta_info  True
# 23          billing_neteller_payout_transactions  True
# 24                  deposits_with_transaction_id  True
# 25                            ps_report_deposits  True
# 26                           rebate_order_rebate  True
# 27                         billing_xpay_payments  True
# 28                                  youscan_dash  True
# 29                           withdrawal_requests  True
# 30                                payment_method  True
# 31                       deposit_requests_hourly  True
# 32                           rebate_user_program  True
# 33                  ps_report_withdrawals_export  True
# 34          payment_transactions_hourly_rejected  True
# 35                            chargebacks_export  True
# 36  fims_to_ps_report_withdrawals_reconciliation  True
# 37                             deposits_enhanced  True
# 38              fims_deposits_for_reconciliation  True
# 39          ps_report_manual_transactions_export  True
# 40                                rebate_payment  True
# 41                     ps_report_comments_export  True
# 42                   payment_transactions_hourly  True
# 43              deposit_requests_every_5_minutes  True
# 44     fims_to_ps_report_deposits_reconciliation  True
# 45                chargebacks_export_prepared_v2  True

# %%
user_count_per_day = segment.groupby(pd.to_datetime(segment["registered_dt"]).dt.date)[
    "user_id"
].count()

user_count_per_day.sort_index()
# Out:
# registered_dt
# 2023-06-01     4190
# 2023-06-02     3870
# 2023-06-03     3600
# 2023-06-04     3902
# 2023-06-05     3935
#               ...
# 2023-12-28    10235
# 2023-12-29     9795
# 2023-12-30     8730
# 2023-12-31     7763
# 2024-01-01     8296
# Name: user_id, Length: 215, dtype: int64

# %%
# %%bigquery registrations_cnt
# SELECT
#   registered_dt,
#   COUNT(DISTINCT user_id) AS daily_registrations_count
# FROM
#   (
#     SELECT
#       DATE (registered_dt) AS registered_dt,
#       user_id,
#       country
#     FROM
#       wh_raw.users
#   )
# WHERE
#   registered_dt BETWEEN '2023-06-01' AND '2024-01-01'
#   AND country IN (
#     'India',
#     'Indonesia',
#     'Mexico',
#     'Brazil',
#     'Malaysia'
#   )
# GROUP BY
#   registered_dt
# ORDER BY
#   registered_dt
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
registrations_cnt
# Out:
#     registered_dt  daily_registrations_count
# 0      2023-06-01                      12107
# 1      2023-06-02                      11222
# 2      2023-06-03                      10623
# 3      2023-06-04                      11543
# 4      2023-06-05                      12094
# ..            ...                        ...
# 210    2023-12-28                      17225
# 211    2023-12-29                      16414
# 212    2023-12-30                      14282
# 213    2023-12-31                      13109
# 214    2024-01-01                      13629
#
# [215 rows x 2 columns]

# %%
merged_df = pd.merge(
    registrations_cnt, user_count_per_day, left_on="registered_dt", right_index=True
)
merged_df.sort_values(by="registered_dt", ascending=True)
# Out:
#     registered_dt  daily_registrations_count  user_id
# 0      2023-06-01                      12107     4357
# 1      2023-06-02                      11222     4046
# 2      2023-06-03                      10623     3732
# 3      2023-06-04                      11543     4011
# 4      2023-06-05                      12093     4105
# ..            ...                        ...      ...
# 210    2023-12-28                      17225    10436
# 211    2023-12-29                      16414     9999
# 212    2023-12-30                      14282     8881
# 213    2023-12-31                      13109     7895
# 214    2024-01-01                      13629     8486
#
# [215 rows x 3 columns]

# %%
# %%bigquery deposited_cnt
# WITH
#   depositswithinanhour AS (
# SELECT
#       b.user_id,
#       CASE
#         WHEN TIMESTAMP_DIFF (MIN(TIMESTAMP_SECONDS(d.created)), MIN(u.registered_dt), HOUR) <= 1 THEN 1
#         ELSE 0
#       END AS deposited_within_an_hour
#     FROM
#       -- wh_raw.deposit_requests d
#       -- left join wh_raw.billing_accounts b
#       -- on d.billing_account_id = b.id
#       -- left join wh_raw.users u on b.user_id =   u.user_id
#     WHERE
#       TIMESTAMP_SECONDS(d.created) >= u.registered_dt
#       AND u.country IN (
#         'India',
#         'Indonesia',
#         'Mexico',
#         'Brazil',
#         'Malaysia'
#       )
#     GROUP BY
#       b.user_id
#   ),
#   users_converted AS (
#     SELECT
#       u.user_id,
#       DATE (u.registered_dt) AS registered_dt,
#       COALESCE(d.deposited_within_an_hour, 0) AS deposited
#     FROM
#       wh_raw.users AS u
#       LEFT JOIN depositswithinanhour AS d ON u.user_id = d.user_id
#       LEFT JOIN amplitude.events_octa_raw_trading_accounts AS ta ON u.user_id = ta.user_id
#       AND ta.platform = 'android'
#       AND server_name = 'real'
#     WHERE
#       DATE (u.registered_dt) BETWEEN '2023-06-01' AND '2024-01-01'
#       AND u.country IN (
#         'India',
#         'Indonesia',
#         'Mexico',
#         'Brazil',
#         'Malaysia'
#       )
#   )
# SELECT
#   registered_dt,
#   SUM(deposited) AS converted_cnt
# FROM
#   users_converted
# GROUP BY
#   registered_dt
# ORDER BY
#   registered_dt ASC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
deposited_cnt
# Out:
#     registered_dt  converted_cnt
# 0      2023-06-01            346
# 1      2023-06-02            360
# 2      2023-06-03            226
# 3      2023-06-04            292
# 4      2023-06-05            368
# ..            ...            ...
# 210    2023-12-28            534
# 211    2023-12-29            265
# 212    2023-12-30            199
# 213    2023-12-31            147
# 214    2024-01-01             92
#
# [215 rows x 2 columns]

# %%
registrations_cnt
# Out:
#     registered_dt  daily_registrations_count
# 0      2023-06-01                      12107
# 1      2023-06-02                      11222
# 2      2023-06-03                      10623
# 3      2023-06-04                      11543
# 4      2023-06-05                      12094
# ..            ...                        ...
# 210    2023-12-28                      17225
# 211    2023-12-29                      16414
# 212    2023-12-30                      14282
# 213    2023-12-31                      13109
# 214    2024-01-01                      13629
#
# [215 rows x 2 columns]

# %%
merged_df = pd.merge(registrations_cnt, user_count_per_day, on="registered_dt").rename(
    columns={"user_id": "segment_cnt"}
)
# merged_df.rename(columns={'user_id': 'segment_cnt'}, inplace=True)
merged_df
# Out:
#     registered_dt  daily_registrations_count  segment_cnt
# 0      2023-06-01                      12107         4357
# 1      2023-06-02                      11222         4046
# 2      2023-06-03                      10623         3732
# 3      2023-06-04                      11543         4011
# 4      2023-06-05                      12093         4105
# ..            ...                        ...          ...
# 210    2023-12-28                      17225        10436
# 211    2023-12-29                      16414         9999
# 212    2023-12-30                      14282         8881
# 213    2023-12-31                      13109         7895
# 214    2024-01-01                      13629         8486
#
# [215 rows x 3 columns]

# %%
merged_df = pd.merge(registrations_cnt, user_count_per_day, on="registered_dt").rename(
    columns={"user_id": "segment_cnt"}
)

merged_df = pd.merge(merged_df, deposited_cnt, on="registered_dt")
merged_df = merged_df[
    [
        "registered_dt",
        "daily_registrations_count",
        "segment_cnt",
        "converted_cnt",
    ]
]

# %%
# %%bigquery overall_conversion
# WITH
#   registeredusers AS (
#     SELECT
#       user_id,
#       country,
#       registered_dt
#     FROM
#       `analytics-147612.wh_raw.users`
#     WHERE
#       DATE(registered_dt) BETWEEN '2023-06-01' AND '2024-01-01'
#       AND country IN (
#         'India',
#         'Indonesia',
#         'Mexico',
#         'Brazil',
#         'Malaysia'
#       )
#   ),
#   androidusers AS (
#     SELECT
#       user_id,
#       MIN(trading_account_created_date) AS first_trading_account_dt
#     FROM
#       `analytics-147612.amplitude.events_octa_raw_trading_accounts`
#     WHERE
#       user_id IN (
#         SELECT
#           user_id
#         FROM
#           registeredusers
#       )
#     GROUP BY
#       1
#   ),
#   deposits AS (
#     SELECT
#       b.user_id as user_id,
#       MIN(TIMESTAMP_SECONDS(d.created)) AS first_deposit_time
#     FROM
#       wh_raw.deposit_requests d
#       left join wh_raw.billing_accounts b
#       on d.billing_account_id = b.id
#       where b.user_id IN (
#         SELECT
#           user_id
#         FROM
#           registeredusers
#       )
#     GROUP BY
#       b.user_id
#   ),
#   converted AS (
#     SELECT
#       ru.user_id,
#       ru.registered_dt,
#       ru.country,
#       au.first_trading_account_dt,
#       d.first_deposit_time,
#       CASE
#         WHEN TIMESTAMP_DIFF(
#           d.first_deposit_time,
#           au.first_trading_account_dt,
#           HOUR
#         ) <= 1 THEN 1
#         ELSE 0
#       END AS deposited_within_an_hour
#     FROM
#       registeredusers AS ru
#       INNER JOIN androidusers AS au ON ru.user_id = au.user_id
#       LEFT JOIN deposits AS d ON ru.user_id = d.user_id
#   )
# SELECT
#   *
# FROM
#   converted
# ;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
p_x = overall_conversion["deposited_within_an_hour"].mean()

# %%
0.0196
# Out:
# 0.02238543442129132

# %%
import requests
from bs4 import BeautifulSoup

# URL of the webpage
url = "https://library.lol/main/658D75E4F3BCE75B68D76A5F126F67D1"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, "html.parser")

    # Extract the book name
    book_name = soup.find("h1").text.strip()
    print(f"Book Name: {book_name}")

    links = soup.find_all("a")
    cloudflare = links[1]["href"]
    ext = cloudflare.split(".")[-1]
    print(ext)
    print(f"Cloudflare Link: {cloudflare}")
else:
    print("Failed to retrieve the webpage")
# Out:
# Book Name: Bayesian Decision Analysis: Principles and Practice
# pdf
# Cloudflare Link: https://cloudflare-ipfs.com/ipfs/bafykbzacecdqh7adiecjjuse5cvmd6nxfslhmcvujvgueythqexsyjjv5xocg?filename=Jim%20Q.%20Smith%20-%20Bayesian%20Decision%20Analysis_%20Principles%20and%20Practice-Cambridge%20University%20Press%20%282010%29.pdf

# %%
import statsmodels.stats.api as sms

# Define parameters
alpha = 0.05
power = 0.8
effect_size = sms.proportion_effectsize(p_x, p_x + 0.00)
sample_size = sms.NormalIndPower().solve_power(
    effect_size, power=power, alpha=alpha, ratio=1.0
)
print(f"Required sample size per group: {int(sample_size)}")
# Out:
# Required sample size per group: 30142

# %%
from statsmodels.stats.power import TTestIndPower, NormalIndPower
from statsmodels.stats.proportion import proportion_effectsize, proportions_ztest


def calculate_mde(base_prop, sample_size, power=0.8, alpha=0.05):
    power_analysis = TTestIndPower()
    effect_size = power_analysis.solve_power(
        effect_size=None,
        power=power,
        alpha=alpha,
        nobs1=sample_size,
        ratio=1,
        alternative="two-sided",
    )
    mde = proportion_effectsize(base_prop, base_prop + effect_size)
    return np.abs(mde), effect_size


def calculate_sample_size(base_rate, effect_size, power=0.8, alpha=0.05):
    effect_size = proportion_effectsize(base_rate, base_rate + effect_size)

    sample_size = TTestIndPower().solve_power(
        effect_size=effect_size,
        power=power,
        alpha=alpha,
        ratio=1,
        alternative="two-sided",
    )

    return int(sample_size), math.ceil(sample_size / 100) * 100


p_x, minimum_detectable_effect = (
    overall_conversion["deposited_within_an_hour"].mean(),
    0.004,
)
sample_size, rounded = calculate_sample_size(p_x, minimum_detectable_effect)
print(f"Required sample size per group: {int(sample_size)+1}")
# Out:
# Required sample size per group: 23304

# %%
# %%bigquery t
# WITH
#   android_reg AS (
#     SELECT
#       user_id,
#       touch_name,
#       visit_time_dt,
#       DATE(visit_time_dt) AS touch_date,
#       touch_position,
#       c.country,
#       device_type,
#       os,
#       registered_dt,
#        -- ROW_NUMBER() OVER (
#       -- PARTITION BY
#       -- user_id
#       -- ORDER BY
#       -- visit_time_dt DESC
#       -- )                          AS touch_number,
#       LAST_VALUE(visit_time_dt) OVER (
#         PARTITION BY
#           user_id
#         ORDER BY
#           visit_time_dt DESC ROWS BETWEEN UNBOUNDED PRECEDING
#           AND UNBOUNDED FOLLOWING
#       ) AS last_touch
#     FROM
#       wh_reporting.touches_with_user_id t
#       LEFT JOIN wh_raw.countries c ON t.country = c.country
#     WHERE
#       touch_position = 'touch_before_reg'
#       AND device_type = 'mobile'
#       AND os = 'android'
#       AND DATE(registered_dt) BETWEEN '2023-06-01' AND '2024-01-01'
#       AND DATE(visit_time_dt) BETWEEN '2023-06-01' AND '2024-01-01'
#       AND c.country IN (
#         'India',
#         'Indonesia',
#         'Mexico',
#         'Brazil',
#         'Malaysia'
#       )
#   ) -- ,
# SELECT
#   touch_date,
#   COUNT(DISTINCT user_id) AS reg_cnt
# FROM
#   android_reg
# GROUP BY
#   touch_date
# ORDER BY
#   touch_date ASC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
